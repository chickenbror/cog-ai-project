# %%
import torch
from torch import nn
from torchvision import transforms # Preprocess jpg images
from PIL import Image
# import numpy as np
import matplotlib.pyplot as plt
import random

# %%
import torchvision # Pre-trained CNN

# %%
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device = 'cuda:2'

# %% [markdown]
# ### Preprocess Flickr8K: Parse captions to lists of ANPs

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
def get_ANP(caption, add_empty_adj=False):
    '''Parses a text and returns a list of adj-noun pairs'''
    doc = nlp(caption)
    ANPs = []
    for i,token in enumerate(doc):
        
        # Look for a noun
        if token.pos_ not in ('NOUN'):
            continue

        noun = token.lemma_.lower() # Noun in lemma form
        try:
            # Look for preceding adj
            if doc[i-1].pos_ == 'ADJ':
                adj = doc[i-1].lemma_.lower() # Adj in lemma form
                ANPs.append((adj, noun))
            else:
                if add_empty_adj:
                    ANPs.append(('-', noun))
        except IndexError:
            pass
    return ANPs

get_ANP(u'Three black dogs and a tri-colored dog playing with each other on the road.', add_empty_adj=True)
# Out:
# 2022-01-20 13:04:49.302237: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# [('black', 'dog'), ('colored', 'dog'), ('-', 'road')]

# %%
from tqdm import tqdm
import pickle

def get_imgs_with_ANPs(fn_caption_file, min_freq=45, keep_empty_adj=False,
                       pickle_fn="saved_fn_anp_dict.pkl"):
    
    # Read previously saved pickle file) => get fn:[ANP...]
    try:
        with open(pickle_fn, "rb") as f:
            print("Reading previously saved dictionary of Filename:Adj-Noun-Pairs...")
            fn_ANP_dict = pickle.load(f)
            
    except FileNotFoundError:
        # Read the txt file => get fn:[ANP...]
        print("Reading captions and looking for Adj-Noun Pairs...")
        with open(fn_caption_file) as f:
            fn_ANP_dict = {}
            lines = [l for l in f]
            for line in tqdm(lines):
                if len(line.split(','))!=2:
                    continue
                fn, cap = line.strip('\n').split(',')
                if fn=='image':
                    continue
                ANPs = get_ANP(cap, add_empty_adj=True)
                if ANPs == []:
                    continue
                fn_ANP_dict[fn] = ANPs
                
        # Save the parsed fn-ANPs dict for future use   
        with open(pickle_fn, "wb") as f:
            pickle.dump(fn_ANP_dict, f)
    
    #===================================================
    #Count the frequency of adjs and nouns
    def count_adj_noun(fn_ANP_dict):
        a_counts, n_counts = {}, {}

        for anp_list in fn_ANP_dict.values():
            for (a,n) in anp_list:
                a_counts[a] = a_counts.get(a,0)+1
                n_counts[n] = n_counts.get(n,0)+1
        return a_counts, n_counts
    
    a_counts, n_counts = count_adj_noun(fn_ANP_dict)  
    if not keep_empty_adj and '-' in a_counts:
        a_counts.pop('-')
    print(f"Before filtering: {len(fn_ANP_dict)} images with ANPs.")
    print(f"{len(a_counts)} adjs, {len(n_counts)} nouns.")
    
    #===================================================
    #Filter adjs and nouns that have appeared minimum N times
    def get_frequent_words(word_count_dict):
        return [w for w,freq in word_count_dict.items() if freq>=min_freq]
    
    print(f"\nAfter filtering: Only keep the adjs or nouns that are annotated in at least {min_freq} images:")
    frequent_adjs = get_frequent_words(a_counts)
    frequent_nouns = get_frequent_words(n_counts)
    ANP_combos = [(a,n) for a in frequent_adjs for n in frequent_nouns]
    print(f"{len(frequent_adjs)} freq adjs X {len(frequent_nouns)} freq nouns = {len(ANP_combos)} possible combinations")
    
    #===================================================
    #Filter images that contain the frequent adjs/nouns
    filtered_fn_ANPs = {}
    for fn, ANPs in fn_ANP_dict.items():
        frequent_ANPs = [(a,n) for a,n in ANPs if a in frequent_adjs and n in frequent_nouns]
        if frequent_ANPs:
            filtered_fn_ANPs[fn]=frequent_ANPs
            
    ANP_set=set()
    for anps in list(filtered_fn_ANPs.values()):
        ANP_set.update(anps)
        
    print(f"{len(filtered_fn_ANPs)} images with {len(ANP_set)} ANPs containing frequent adjs and nouns.")
    
    return frequent_adjs, frequent_nouns, ANP_combos, filtered_fn_ANPs

# %%
flickr8k_path = '/scratch/lt2318-h21-resources/03-image-captioning/data/flickr8k/'
flickr8K_caps = flickr8k_path + 'captions.txt'
flickr8K_imgs = flickr8k_path + 'Images/'

adj_classes, noun_classes, ANP_classes, fn_ANPs = get_imgs_with_ANPs(flickr8K_caps, min_freq=50)
# Out:
# Reading previously saved dictionary of Filename:Adj-Noun-Pairs...
# Before filtering: 7616 images with ANPs.
# 654 adjs, 1091 nouns.
#
# After filtering: Only keep the adjs or nouns that are annotated in at least 50 images:
# 27 freq adjs X 29 freq nouns = 783 possible combinations
# 4258 images with 254 ANPs containing frequent adjs and nouns.

# %% [markdown]
# #### Helper functions to turn raw data into PyTorch tensors

# %%
def file_to_tensor(img_path):
    # (PIL.Image obj) => pt tensor 3x224x224
    # load jpg directly as tensor of CxHxW to avoid needing converting from numpy and permuting

    preprocess_fn = transforms.Compose([
        transforms.Resize(230),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])
        ])
    
    # PIL Img obj
    with Image.open(img_path) as img:
        img_tensor = preprocess_fn(img)
        return img_tensor

def augment_img_tensors(batch_tensors):
#     tensor_to_PIL = transforms.ToPILImage()
    augment_fn = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.RandomHorizontalFlip(p=0.5),
#                     transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0),
                    transforms.RandomAffine(degrees=15, translate=(0.1, 0.1), scale=(0.8, 1.2),
                                            shear=None, interpolation=transforms.InterpolationMode.NEAREST,
                                            fill=(255, 255, 255)),
                    transforms.ToTensor(),
                    ])
    # tensors->PIL objs-> randomly change angles, flip, etc ->new tensors
    new_tensors = [augment_fn(x) for x in batch_tensors]
    new_tensors = torch.stack(new_tensors)
    return new_tensors

def multilabels_to_tensor(list_labels, list_classes):
    '''Returns a tensor of length = num_classes, which is filled with 0 or 1'''
    zeros = torch.zeros(len(list_classes))
    for label in list_labels:
        if label in list_classes:
            idx = list_classes.index(label)
            zeros[idx] = 1
    return zeros

def convert_fn_anp_to_xy(fn_anp, img_path=flickr8K_imgs):
    '''Converst a list of (filename, [labels...]) to 
    a list of (img_tensor, multilabels_tensor) tuples'''
    xy=[] 
    for fn, anp_list in tqdm(fn_anp):
        img = file_to_tensor(img_path+fn)
        anp_labels = multilabels_to_tensor(anp_list, ANP_classes)
        
        adjs, nouns = zip(*anp_list)
        adj_labels = multilabels_to_tensor(adjs, adj_classes)
        noun_labels = multilabels_to_tensor(nouns, noun_classes)
        xy.append((img, anp_labels, adj_labels, noun_labels))
    return xy

# %% [markdown]
# #### Train and val datasets: (img: tensor, ANP_labels: tensor, adj_labels: tensor, noun_labels: tensor)

# %%
def train_val_split(dataset, val_portion=0.2):
    random.shuffle(dataset)
    val_split = int( len(dataset) * val_portion)
    train, val = dataset[val_split:], dataset[:val_split]
    return train, val

data = list(fn_ANPs.items())

train_fn_anp, val_fn_anp = train_val_split(data)
len(train_fn_anp), len(val_fn_anp) # Numbers of train imgs and val imgs
# Out:
# (3407, 851)

# %%
trainXY = convert_fn_anp_to_xy(train_fn_anp)
valXY = convert_fn_anp_to_xy(val_fn_anp)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 3407/3407 [01:10<00:00, 48.04it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 851/851 [00:17<00:00, 48.48it/s]

# %% [markdown]
# ### Model that outputs multiple labels:
# ### ResNet -> fc(num_classes) -> Sigmoid

# %%
class ResnetTagger(nn.Module):

    def __init__(self, n_classes):
        super().__init__()

        resnet = torchvision.models.resnet101(pretrained=True) # Pretrained ResNet101 model
        resnet.fc = nn.Sequential(
            nn.Dropout(p=0.33),
            nn.Linear(in_features=resnet.fc.in_features, out_features=n_classes)
        )

        self.base_model = resnet
        self.sigm = nn.Sigmoid()

    def forward(self, x):
        out = self.base_model(x)
        return self.sigm(out)

# %%
class CrossTagger(nn.Module):

    def __init__(self, n_adjs, n_nouns, hiddensize=512, consider_anp_targets=False):
        super().__init__()
        
        resnet = torchvision.models.resnet101(pretrained=True) # Pretrained ResNet101 model
        
        # This layer is shared for both adj&noun
        resnet.fc = nn.Sequential(
            nn.Linear(in_features=resnet.fc.in_features, out_features=hiddensize), 
        )
        self.base_model = resnet
        
        # Separate FCs for adj/noun
        self.adj_fc = nn.Sequential(
            nn.Dropout(p=0.33),
            nn.Linear(in_features=hiddensize, out_features=n_adjs),
        )
        
        self.noun_fc = nn.Sequential(
            nn.Dropout(p=0.33),
            nn.Linear(in_features=hiddensize, out_features=n_nouns),
        )
        
        self.cross_fc = nn.Sequential(
            nn.Linear(in_features=n_adjs*n_nouns, out_features=hiddensize),
            nn.ReLU(),
            nn.Linear(in_features=hiddensize, out_features=n_adjs*n_nouns),
#             nn.ReLU(),
        )
        
        self.sigm = nn.Sigmoid()
        self.consider_anp_targets = consider_anp_targets


    def forward(self, x):
        # Train to predict adj/noun separately
        adj_reps, noun_reps = self.adj_fc(self.base_model(x)), self.noun_fc(self.base_model(x))
        adj_out, noun_out = self.sigm(adj_reps), self.sigm(noun_reps)
        
        if self.consider_anp_targets:
            # Multiply the adj/noun reps and go thru another fc layer
            cross_reps = self.cross_multiply(adj_reps, noun_reps) # AxN matrix of size= B, num_adjs*num_nouns 
            cross_reps = self.cross_fc(cross_reps)
            cross_out = self.sigm(cross_reps)
        else:
            # Simply multiply the adj/noun sigmoids
            cross_out = self.cross_multiply(adj_out, noun_out)
        
        return cross_out, (adj_out, noun_out)
    
    def cross_multiply(self, t1,t2):
        '''
        Given two tensors of size BxN and BxM, return a tensor of size Bx(N*M),
        where each element in dim1 is i*j for i in N and for j in M
        '''
        # Each element in out-tensor is cross-multiplication of N and M
        out = torch.einsum("di,dj->dij", (t1,t2))
        # Flatten all but the batch dim
        return torch.flatten(out, start_dim=1)

# %% [markdown]
# ### Train-loop function

# %%
from torch.utils.data import DataLoader
from datetime import datetime

def train(model, model_name, trainXY, valXY, label_idx,
          device=device, augment_imgs=True,
          batch_size=32, epochs = 10, learning_rate = 1e-4):
    
    model=model.to(device)

    # Grad descend / Loss fn / Dataset iterators
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.BCELoss()

    train_loader = DataLoader(trainXY, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(valXY, batch_size=batch_size, shuffle=False)

    # Epoch (Train+Val) loop

    # Record time lapses and stats in each epoch 
    train_start_time = datetime.now()
    epoch_train_val_losses = []

    for e in range(1,epochs+1):
        start_time = datetime.now()

        #===TRAIN==============================================
        model.train()
        train_loss = 0
        for i, xy in enumerate(train_loader):
            imgs = xy[0]
            if augment_imgs:
                imgs = augment_img_tensors(imgs) #Random augment train imgs
                
            targets = xy[label_idx] # 1,2,3 for anp, adj, noun
            imgs, targets = imgs.to(device), targets.to(device)

            output = model(imgs)

            loss = criterion(output, targets)
            train_loss += loss.item()

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            print(f"Epoch {e} avg train loss {train_loss/(i+1)}", end='\r')
        print()
        
        #===Save model============================================
        torch.save(model, f"trained-models/{model_name}.pt")

        #===VAL/TEST==============================================
        model.eval()
        with torch.no_grad():
            val_loss = 0
            for i, xy in enumerate(val_loader):
                imgs = xy[0] # No augment
                targets = xy[label_idx]
                imgs, targets = imgs.to(device), targets.to(device)
                output = model(imgs)

                loss = criterion(output, targets)
                val_loss += loss.item()
                print(f"Epoch {e} avg val loss   {val_loss/(i+1)}", end='\r')
        print()

        #===EPOCH INFO and STATS=======================================
        lapsed_time = datetime.now()-start_time
        total_lapsed_time = datetime.now()-train_start_time
        print(f"Epoch {e} train+val time:",str(lapsed_time).split('.')[0], 
              "Total lapsed time:", str(total_lapsed_time).split('.')[0])
        epoch_train_val_losses.append((train_loss, val_loss))

    print('DONE!')
    # ===Draw the line chart===================================
    the_epochs = list(range(1,epochs+1)) # X-axis
    train_losses, val_losses = zip(*epoch_train_val_losses)

    # Lines
    plt.plot(the_epochs, train_losses, label='train loss')
    plt.plot(the_epochs, val_losses, label='val loss')


    plt.title('Losses over iterations')
    plt.xlabel('epoch')
    plt.ylabel('train/val loss')
    plt.legend()
    plt.show()
    
    return model

# %%
def train_crossmodel(model, model_name, trainXY, valXY,
          device=device, consider_anp_targets=False, augment_imgs=True, 
          batch_size=32, epochs = 10, learning_rate = 1e-4):
    
    model.consider_anp_targets = consider_anp_targets
    if consider_anp_targets and model.consider_anp_targets:
        print('Consider ANP gold labels when training.')
    
    model=model.to(device)

    # Grad descend / Loss fn / Dataset iterators
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.BCELoss()

    train_loader = DataLoader(trainXY, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(valXY, batch_size=batch_size, shuffle=False)

    # Epoch (Train+Val) loop

    # Record time lapses and stats in each epoch 
    train_start_time = datetime.now()
    epoch_train_val_losses = []

    for e in range(1,epochs+1):
        start_time = datetime.now()

        #===TRAIN==============================================
        model.train()
        train_loss = 0
        for i, xy in enumerate(train_loader):
            imgs = xy[0]
            if augment_imgs:
                imgs = augment_img_tensors(imgs) #Random augment train imgs
            adj_targets, noun_targets = xy[2:] # 1,2,3 for anp, adj, noun
            
            imgs, adj_targets, noun_targets = imgs.to(device), adj_targets.to(device), noun_targets.to(device)

            cross_out, (adj_out, noun_out) = model(imgs)
            
            # The loss is based on learning adjs/nouns separately
            if consider_anp_targets:
                anp_targets = xy[1].to(device)
                loss = criterion(cross_out, anp_targets) + criterion(adj_out, adj_targets) + criterion(noun_out, noun_targets)
            else:
                loss = criterion(adj_out, adj_targets) + criterion(noun_out, noun_targets)
            train_loss += loss.item()

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            print(f"Epoch {e} avg train loss {train_loss/(i+1)}", end='\r')
        print()
        
        #===Save model============================================
        torch.save(model, f"trained-models/{model_name}.pt")

        #===VAL/TEST==============================================
        model.eval()
        with torch.no_grad():
            val_loss = 0
            for i, xy in enumerate(val_loader):
                imgs = xy[0] # No augment
                adj_targets, noun_targets = xy[2:] # 1,2,3 for anp, adj, noun
                imgs, adj_targets, noun_targets = imgs.to(device), adj_targets.to(device), noun_targets.to(device)
                cross_out, (adj_out, noun_out) = model(imgs)

                if consider_anp_targets:
                    anp_targets = xy[1].to(device)
                    loss = criterion(cross_out, anp_targets) + criterion(adj_out, adj_targets) + criterion(noun_out, noun_targets)
                else:
                    loss = criterion(adj_out, adj_targets) + criterion(noun_out, noun_targets)
                val_loss += loss.item()
                print(f"Epoch {e} avg val loss   {val_loss/(i+1)}", end='\r')
        print()

        #===EPOCH INFO and STATS=======================================
        lapsed_time = datetime.now()-start_time
        total_lapsed_time = datetime.now()-train_start_time
        print(f"Epoch {e} train+val time:",str(lapsed_time).split('.')[0], 
              "Total lapsed time:", str(total_lapsed_time).split('.')[0])
        epoch_train_val_losses.append((train_loss, val_loss))

    print('DONE!')
    # ===Draw the line chart===================================
    the_epochs = list(range(1,epochs+1)) # X-axis
    train_losses, val_losses = zip(*epoch_train_val_losses)

    # Lines
    plt.plot(the_epochs, train_losses, label='train loss')
    plt.plot(the_epochs, val_losses, label='val loss')


    plt.title('Losses over iterations')
    plt.xlabel('epoch')
    plt.ylabel('train/val loss')
    plt.legend()
    plt.show()
    
    return model

# %% [markdown]
# ### Initialise new models and train **(Skip this part if already saved trained models)**

# %%
anp_tagger = ResnetTagger(len(ANP_classes))
anp_tagger = train(anp_tagger, "anp-tagger", trainXY, valXY, label_idx=1)
# Out:
# /home/gusliahs@GU.GU.SE/.local/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch 1 avg train loss 0.09287059388915513
# Epoch 1 avg val loss   0.015742953590772777
# Epoch 1 train+val time: 0:00:56 Total lapsed time: 0:00:56
# Epoch 2 avg train loss 0.009614712310624178
# Epoch 2 avg val loss   0.012487101437592948
# Epoch 2 train+val time: 0:00:56 Total lapsed time: 0:01:52
# Epoch 3 avg train loss 0.008541439076728919
# Epoch 3 avg val loss   0.011056392419117468
# Epoch 3 train+val time: 0:00:56 Total lapsed time: 0:02:48
# Epoch 4 avg train loss 0.008096060946270406
# Epoch 4 avg val loss   0.009855092779077866
# Epoch 4 train+val time: 0:00:56 Total lapsed time: 0:03:45
# Epoch 5 avg train loss 0.0078052233939415945
# Epoch 5 avg val loss   0.009478233375207142
# Epoch 5 train+val time: 0:00:56 Total lapsed time: 0:04:41
# Epoch 6 avg train loss 0.0076356625062561485
# Epoch 6 avg val loss   0.009724921960797574
# Epoch 6 train+val time: 0:00:56 Total lapsed time: 0:05:37
# Epoch 7 avg train loss 0.0075153009400259114
# Epoch 7 avg val loss   0.009798427560815105
# Epoch 7 train+val time: 0:00:55 Total lapsed time: 0:06:33
# Epoch 8 avg train loss 0.0073865492279841525
# Epoch 8 avg val loss   0.010007196554431209
# Epoch 8 train+val time: 0:00:56 Total lapsed time: 0:07:29
# Epoch 9 avg train loss 0.0072848860992588735
# Epoch 9 avg val loss   0.009896461231013148
# Epoch 9 train+val time: 0:00:56 Total lapsed time: 0:08:26
# Epoch 10 avg train loss 0.0071691826734448154
# Epoch 10 avg val loss   0.010046948713284952
# Epoch 10 train+val time: 0:00:56 Total lapsed time: 0:09:22
# DONE!

# %%
#Train adj multi-label classifier
adj_tagger = ResnetTagger(n_classes=len(adj_classes))
adj_tagger = train(adj_tagger, 'adj-tagger', trainXY=trainXY, valXY=valXY, label_idx=2)
# Out:
# Epoch 1 avg train loss 0.20428571341750779
# Epoch 1 avg val loss   0.19448843929502729
# Epoch 1 train+val time: 0:00:57 Total lapsed time: 0:00:57
# Epoch 2 avg train loss 0.14147701267605634
# Epoch 2 avg val loss   0.17916687108852244
# Epoch 2 train+val time: 0:00:54 Total lapsed time: 0:01:52
# Epoch 3 avg train loss 0.13640475112979658
# Epoch 3 avg val loss   0.18033599301620765
# Epoch 3 train+val time: 0:00:54 Total lapsed time: 0:02:47
# Epoch 4 avg train loss 0.13142648513350536
# Epoch 4 avg val loss   0.18413237233956656
# Epoch 4 train+val time: 0:00:54 Total lapsed time: 0:03:42
# Epoch 5 avg train loss 0.12536857123965414
# Epoch 5 avg val loss   0.19983059498998854
# Epoch 5 train+val time: 0:00:53 Total lapsed time: 0:04:36
# Epoch 6 avg train loss 0.12118816501069292
# Epoch 6 avg val loss   0.20436480310228136
# Epoch 6 train+val time: 0:00:53 Total lapsed time: 0:05:30
# Epoch 7 avg train loss 0.11278137042422161
# Epoch 7 avg val loss   0.26985677745607163
# Epoch 7 train+val time: 0:00:53 Total lapsed time: 0:06:23
# Epoch 8 avg train loss 0.10489293549940965
# Epoch 8 avg val loss   0.33319006584308763
# Epoch 8 train+val time: 0:00:53 Total lapsed time: 0:07:17
# Epoch 9 avg train loss 0.09819540339652623
# Epoch 9 avg val loss   0.21863778101073372
# Epoch 9 train+val time: 0:00:53 Total lapsed time: 0:08:11
# Epoch 10 avg train loss 0.08901028644955047
# Epoch 10 avg val loss   0.22396068164595852
# Epoch 10 train+val time: 0:00:53 Total lapsed time: 0:09:05
# DONE!

# %%
#Train noun multi-label classifier
noun_tagger = ResnetTagger(n_classes=len(noun_classes))
noun_tagger = train(noun_tagger, 'noun-tagger', trainXY=trainXY, valXY=valXY, label_idx=3)
# Out:
# Epoch 1 avg train loss 0.19141077438247545
# Epoch 1 avg val loss   0.21355648449173683
# Epoch 1 train+val time: 0:00:56 Total lapsed time: 0:00:56
# Epoch 2 avg train loss 0.12157169200271091
# Epoch 2 avg val loss   0.22543615489094346
# Epoch 2 train+val time: 0:00:55 Total lapsed time: 0:01:52
# Epoch 3 avg train loss 0.11467576096548099
# Epoch 3 avg val loss   0.20077636341253915
# Epoch 3 train+val time: 0:00:57 Total lapsed time: 0:02:49
# Epoch 4 avg train loss 0.10964490793575758
# Epoch 4 avg val loss   0.21936843902976425
# Epoch 4 train+val time: 0:00:56 Total lapsed time: 0:03:46
# Epoch 5 avg train loss 0.10329471779203861
# Epoch 5 avg val loss   0.20642477991404357
# Epoch 5 train+val time: 0:00:56 Total lapsed time: 0:04:43
# Epoch 6 avg train loss 0.09791101132319352
# Epoch 6 avg val loss   0.21309134143370173
# Epoch 6 train+val time: 0:00:57 Total lapsed time: 0:05:40
# Epoch 7 avg train loss 0.09116007882022412
# Epoch 7 avg val loss   0.17151144643624625
# Epoch 7 train+val time: 0:00:57 Total lapsed time: 0:06:38
# Epoch 8 avg train loss 0.08320074740832097
# Epoch 8 avg val loss   0.20196050019175918
# Epoch 8 train+val time: 0:00:57 Total lapsed time: 0:07:35
# Epoch 9 avg train loss 0.07629122974995141
# Epoch 9 avg val loss   0.21582338434678536
# Epoch 9 train+val time: 0:00:58 Total lapsed time: 0:08:33
# Epoch 10 avg train loss 0.07018497039642294
# Epoch 10 avg val loss   0.24010239596720095
# Epoch 10 train+val time: 0:00:58 Total lapsed time: 0:09:31
# DONE!

# %%
cross_anp_tagger_A = CrossTagger( len(adj_classes), len(noun_classes) )
cross_anp_tagger_A = train_crossmodel( cross_anp_tagger_A, 'cross-anp-tagger-A', trainXY, valXY)
# Out:
# Epoch 1 avg train loss 0.37161522087092713
# Epoch 1 avg val loss   0.6926376046957793
# Epoch 1 train+val time: 0:01:32 Total lapsed time: 0:01:32
# Epoch 2 avg train loss 0.27890015261195536
# Epoch 2 avg val loss   0.6614745524194505
# Epoch 2 train+val time: 0:01:31 Total lapsed time: 0:03:04
# Epoch 3 avg train loss 0.26746054063333534
# Epoch 3 avg val loss   0.46495002728921416
# Epoch 3 train+val time: 0:01:31 Total lapsed time: 0:04:35
# Epoch 4 avg train loss 0.25689052894850756
# Epoch 4 avg val loss   0.5873629517025418
# Epoch 4 train+val time: 0:01:31 Total lapsed time: 0:06:07
# Epoch 5 avg train loss 0.24978713162034472
# Epoch 5 avg val loss   0.5381736159324646
# Epoch 5 train+val time: 0:01:31 Total lapsed time: 0:07:38
# Epoch 6 avg train loss 0.23993713039661121
# Epoch 6 avg val loss   0.5425950597833704
# Epoch 6 train+val time: 0:01:32 Total lapsed time: 0:09:10
# Epoch 7 avg train loss 0.23131063023460247
# Epoch 7 avg val loss   0.5991615255673727
# Epoch 7 train+val time: 0:01:31 Total lapsed time: 0:10:42
# Epoch 8 avg train loss 0.22148170203806083
# Epoch 8 avg val loss   0.8787838927021733
# Epoch 8 train+val time: 0:01:32 Total lapsed time: 0:12:14
# Epoch 9 avg train loss 0.21031446713153448
# Epoch 9 avg val loss   0.6045487258169386
# Epoch 9 train+val time: 0:01:31 Total lapsed time: 0:13:45
# Epoch 10 avg train loss 0.19867127409605223
# Epoch 10 avg val loss   0.7698216217535513
# Epoch 10 train+val time: 0:01:31 Total lapsed time: 0:15:17
# DONE!

# %%
cross_anp_tagger_B = CrossTagger( len(adj_classes), len(noun_classes) )
cross_anp_tagger_B = train_crossmodel(cross_anp_tagger_B, 'cross-anp-tagger-B', trainXY, valXY, 
                                      consider_anp_targets=True )
# Out:
# Consider ANP gold labels when training.
# Epoch 1 avg train loss 0.46571006006169546
# Epoch 1 avg val loss   0.48509128336553225
# Epoch 1 train+val time: 0:01:32 Total lapsed time: 0:01:32
# Epoch 2 avg train loss 0.28783342409356734
# Epoch 2 avg val loss   0.46108474554838965
# Epoch 2 train+val time: 0:01:31 Total lapsed time: 0:03:04
# Epoch 3 avg train loss 0.27637281972114176
# Epoch 3 avg val loss   0.47933784347993364
# Epoch 3 train+val time: 0:01:31 Total lapsed time: 0:04:36
# Epoch 4 avg train loss 0.26778576432544493
# Epoch 4 avg val loss   0.5932615840876544
# Epoch 4 train+val time: 0:01:32 Total lapsed time: 0:06:08
# Epoch 5 avg train loss 0.25924382323973654
# Epoch 5 avg val loss   0.44284690640590807
# Epoch 5 train+val time: 0:01:31 Total lapsed time: 0:07:39
# Epoch 6 avg train loss 0.24897463355108956
# Epoch 6 avg val loss   0.47838324749911275
# Epoch 6 train+val time: 0:01:31 Total lapsed time: 0:09:11
# Epoch 7 avg train loss 0.24234938913973691
# Epoch 7 avg val loss   0.48944038925347505
# Epoch 7 train+val time: 0:01:30 Total lapsed time: 0:10:42
# Epoch 8 avg train loss 0.23363549199616798
# Epoch 8 avg val loss   0.42457121831399425
# Epoch 8 train+val time: 0:01:31 Total lapsed time: 0:12:13
# Epoch 9 avg train loss 0.21991068793234425
# Epoch 9 avg val loss   0.39506575796339257
# Epoch 9 train+val time: 0:01:32 Total lapsed time: 0:13:45
# Epoch 10 avg train loss 0.20955863553229895
# Epoch 10 avg val loss   0.41788806738676853
# Epoch 10 train+val time: 0:01:31 Total lapsed time: 0:15:17
# DONE!

# %% [markdown]
# ### Load previously trained-and-saved models

# %%
anp_tagger = torch.load('trained-models/anp-tagger.pt')
adj_tagger = torch.load('trained-models/adj-tagger.pt')
noun_tagger = torch.load('trained-models/noun-tagger.pt')

# %%
cross_anp_tagger_A = torch.load('trained-models/cross-anp-tagger-A.pt')
cross_anp_tagger_B = torch.load('trained-models/cross-anp-tagger-B.pt')

# %% [markdown]
# ### See how models perform by inputting image and print the predicted labels

# %%
def visualise_pred(img_fn, model_classes_dict, dataset=fn_ANPs,
                   img_path=flickr8K_imgs, threshold=0.1):
    '''Use an image as input and compare the original tagging vs the model-predicted tagging'''
    
    #---------------------------------
    if img_fn in dataset:
        gold_labels = dataset[img_fn]
    else:
        gold_labels = None
        
    print(f"Gold labels:", gold_labels)
    #---------------------------------
    
    test_bat = file_to_tensor(img_path+img_fn).unsqueeze(0) # turn to a batchsize=1 tensor
    
    #---------------------------------
    for model, classes in model_classes_dict.items():
        model.eval()
        with torch.no_grad():
            test_bat = test_bat.to(device)
            out = model(test_bat)
            if len(out)>1: # cross_out, (a_out, n_out)
                out = out[0] 

        out=(out>threshold).float()
        predicted_indices = (out[0]==1.0).nonzero(as_tuple=True)[0] # indices of values that are 1
        predicted_labels = [classes[i] for i in predicted_indices]
        
        print(f"Predicted:", predicted_labels)
        print()
        
    #---------------------------------
    with Image.open(img_path+img_fn) as pic:
        plt.axis('off') # hide the axes on the sides
        plt.imshow(pic)

# %%
visualise_pred('2229509318_be3fef006b.jpg', {cross_anp_tagger_A:ANP_classes}, threshold=0.0005)
# Out:
# Gold labels: [('large', 'dog'), ('pink', 'jacket')]
# Predicted: [('red', 'shirt'), ('green', 'shirt'), ('black', 'shirt'), ('several', 'shirt')]
# /home/gusliahs@GU.GU.SE/.local/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %%
visualise_pred('2229509318_be3fef006b.jpg', {cross_anp_tagger_B:ANP_classes}, threshold=0.0005)
# Out:
# Gold labels: [('large', 'dog'), ('pink', 'jacket')]
# Predicted: [('little', 'boy'), ('young', 'boy'), ('red', 'shirt'), ('brown', 'dog')]

# %%
visualise_pred('2229509318_be3fef006b.jpg', {adj_tagger:adj_classes}, threshold=0.1)
visualise_pred('2229509318_be3fef006b.jpg', {noun_tagger:noun_classes}, threshold=0.005)
# Out:
# Gold labels: [('large', 'dog'), ('pink', 'jacket')]
# Predicted: ['young', 'green', 'white']
#
# Gold labels: [('large', 'dog'), ('pink', 'jacket')]
# Predicted: ['man', 'child', 'shirt', 'field', 'people', 'rock', 'kid', 'jacket', 'mountain', 'helmet', 'pant', 'short', 'wave']

# %%
fn, _ = random.choice(val_fn_anp)
# '2229509318_be3fef006b.jpg'
# 3174196837_800689a2f3.jpg
# 241347547_902725b9f8.jpg
print(fn)
visualise_pred(fn, {anp_tagger:ANP_classes}, threshold=0.08)
# Out:
# 3078844565_16e9cdcea2.jpg
# Gold labels: [('white', 'shirt')]
# Predicted: [('young', 'girl'), ('young', 'child'), ('young', 'boy'), ('red', 'shirt')]

# %%
fn, _ = random.choice(val_fn_anp)
models_and_classes = {anp_tagger:ANP_classes,
                      adj_tagger:adj_classes,
                      noun_tagger:noun_classes, 
                      cross_anp_tagger_A:ANP_classes, 
                      cross_anp_tagger_B:ANP_classes, 
                     }

visualise_pred(fn, models_and_classes, threshold=0.001)
# Out:
# Gold labels: [('several', 'dog')]
# Predicted: [('little', 'girl'), ('little', 'dress'), ('little', 'man'), ('little', 'child'), ('little', 'dog'), ('little', 'shirt'), ('little', 'ball'), ('little', 'field'), ('little', 'toy'), ('little', 'boy'), ('little', 'people'), ('little', 'area'), ('little', 'kid'), ('little', 'woman'), ('little', 'jacket'), ('little', 'mountain'), ('little', 'helmet'), ('little', 'short'), ('little', 'building'), ('little', 'coat'), ('little', 'hair'), ('little', 'collar'), ('little', 'uniform'), ('pink', 'girl'), ('pink', 'dress'), ('pink', 'man'), ('pink', 'hat'), ('pink', 'child'), ('pink', 'dog'), ('pink', 'shirt'), ('pink', 'ball'), ('pink', 'toy'), ('pink', 'boy'), ('pink', 'people'), ('pink', 'area'), ('pink', 'water'), ('pink', 'rock'), ('pink', 'kid'), ('pink', 'woman'), ('pink', 'jacket'), ('pink', 'helmet'), ('pink', 'pant'), ('pink', 'short'), ('pink', 'building'), ('pink', 'coat'), ('pink', 'hair'), ('wooden', 'girl'), ('wooden', 'dress'), ('wooden', 'man'), ('wooden', 'child'), ('wooden', 'grass'), ('wooden', 'shirt'), ('wooden', 'ball'), ('wooden', 'field'), ('wooden', 'toy'), ('wooden', 'boy'), ('wooden', 'people'), ('wooden', 'rock'), ('wooden', 'jacket'), ('wooden', 'mountain'), ('wooden', 'helmet'), ('wooden', 'pant'), ('wooden', 'short'), ('wooden', 'wave'), ('wooden', 'building'), ('wooden', 'coat'), ('wooden', 'collar'), ('wooden', 'uniform'), ('young', 'girl'), ('young', 'man'), ('young', 'hat'), ('young', 'child'), ('young', 'dog'), ('young', 'shirt'), ('young', 'ball'), ('young', 'field'), ('young', 'toy'), ('young', 'boy'), ('young', 'people'), ('young', 'kid'), ('young', 'woman'), ('young', 'mountain'), ('young', 'helmet'), ('young', 'pant'), ('young', 'short'), ('young', 'wave'), ('young', 'coat'), ('young', 'hair'), ('young', 'collar'), ('young', 'uniform'), ('orange', 'dress'), ('orange', 'man'), ('orange', 'hat'), ('orange', 'child'), ('orange', 'dog'), ('orange', 'shirt'), ('orange', 'ball'), ('orange', 'field'), ('orange', 'toy'), ('orange', 'people'), ('orange', 'water'), ('orange', 'kid'), ('orange', 'woman'), ('orange', 'jacket'), ('orange', 'helmet'), ('orange', 'pant'), ('orange', 'short'), ('orange', 'building'), ('orange', 'coat'), ('orange', 'hair'), ('orange', 'collar'), ('orange', 'uniform'), ('small', 'girl'), ('small', 'dress'), ('small', 'child'), ('small', 'dog'), ('small', 'shirt'), ('small', 'ball'), ('small', 'field'), ('small', 'toy'), ('small', 'boy'), ('small', 'water'), ('small', 'rock'), ('small', 'kid'), ('small', 'woman'), ('small', 'jacket'), ('small', 'mountain'), ('small', 'helmet'), ('small', 'pant'), ('small', 'short'), ('small', 'wave'), ('small', 'building'), ('small', 'coat'), ('small', 'collar'), ('small', 'uniform'), ('red', 'girl'), ('red', 'dress'), ('red', 'man'), ('red', 'hat'), ('red', 'grass'), ('red', 'dog'), ('red', 'shirt'), ('red', 'ball'), ('red', 'field'), ('red', 'toy'), ('red', 'people'), ('red', 'water'), ('red', 'rock'), ('red', 'kid'), ('red', 'jacket'), ('red', 'mountain'), ('red', 'helmet'), ('red', 'pant'), ('red', 'short'), ('red', 'wave'), ('red', 'building'), ('red', 'coat'), ('red', 'hair'), ('red', 'collar'), ('red', 'uniform'), ('green', 'girl'), ('green', 'dress'), ('green', 'man'), ('green', 'hat'), ('green', 'grass'), ('green', 'dog'), ('green', 'shirt'), ('green', 'ball'), ('green', 'field'), ('green', 'toy'), ('green', 'people'), ('green', 'area'), ('green', 'water'), ('green', 'rock'), ('green', 'kid'), ('green', 'woman'), ('green', 'jacket'), ('green', 'mountain'), ('green', 'pant'), ('green', 'short'), ('green', 'wave'), ('green', 'building'), ('green', 'coat'), ('green', 'hair'), ('green', 'collar'), ('white', 'girl'), ('white', 'dress'), ('white', 'man'), ('white', 'hat'), ('white', 'child'), ('white', 'grass'), ('white', 'dog'), ('white', 'shirt'), ('white', 'ball'), ('white', 'field'), ('white', 'toy'), ('white', 'people'), ('white', 'area'), ('white', 'water'), ('white', 'jacket'), ('white', 'mountain'), ('white', 'helmet'), ('white ...
#
# Predicted: ['young', 'blue', 'several', 'old']
#
# Predicted: ['girl', 'man', 'hat', 'child', 'grass', 'shirt', 'ball', 'field', 'toy', 'boy', 'people', 'area', 'water', 'rock', 'kid', 'jacket', 'mountain', 'helmet', 'pant', 'short', 'wave', 'coat', 'hair', 'collar']
#
# Predicted: [('red', 'shirt'), ('black', 'shirt')]
#
# Predicted: []

# %%
fn = 'pinkdog2.jpg'
visualise_pred(fn, models_and_classes, img_path='', threshold=0.11)
# Out:
# Gold labels: None
# Predicted: [('little', 'boy'), ('young', 'girl'), ('young', 'man'), ('young', 'child'), ('young', 'boy')]
#
# Predicted: ['several']
#
# Predicted: ['man']
#
# Predicted: []
#
# Predicted: []

# %%
test_bat = file_to_tensor('pinkdog1.jpg').unsqueeze(0) # turn to a batchsize=1 tensor
adj_tagger.eval()
with torch.no_grad():
    test_bat = test_bat.to(device)
    aout = adj_tagger(test_bat)
#     aout = (aout>0.1).int()
aout.shape
# Out:
# torch.Size([1, 27])

# %%
# test_bat = file_to_tensor('pinkdog1.jpg').unsqueeze(0) # turn to a batchsize=1 tensor
noun_tagger.eval()
with torch.no_grad():
    test_bat = test_bat.to(device)
    nout = noun_tagger(test_bat)
#     nout = (nout>0.1).int()
nout.shape
# Out:
# torch.Size([1, 29])

# %%
def cross_multiply(t1,t2):
    '''
    Given two tensors of size BxN and BxM,
    return a tensor of size Bx(N*M) where
    each element is i*j for i in N and for j in M
    '''
    
    # Each element in out-tensor is cross-multiplication of N and M
    out = torch.einsum("di,dj->dij", (t1,t2))
    # Flatten all but the batch dim
    torch.flatten(out, start_dim=1)

    return out

# %%
crossout = crossmul_tensors(aout,nout)
crossout = (crossout>0.15).int() # turn to 1|0 if above/below threshold
pred_idx = (crossout[0]==1.0).nonzero(as_tuple=True)[0]
pred_labels = [ANP_classes[i] for i in pred_idx]
pred_labels
# Out:
# [('little', 'girl'), ('pink', 'girl'), ('pink', 'dog')]

# %%
embed_fn = torch.nn.Embedding(27+29, 100, sparse=True)
embed_fn.to(device)
a_emb = embed_fn(aout.int())
n_emb = embed_fn(nout.int())

# %%
a_emb.shape, n_emb.shape
# Out:
# (torch.Size([1, 27, 100]), torch.Size([1, 29, 100]))

# %%
torch.cat((aout,nout), dim=1).shape
# Out:
# torch.Size([1, 56])

# %%
torch.cat((a_emb,n_emb), dim=1).shape
# Out:
# torch.Size([1, 56, 100])

# %%
# adj_tagger -> A labels
# noun_tagger -> N labels
# generate AxN labels for ANP [1,0,1,...]
# --> use as
